# %%
# seaborn: 建立在 matplotlib 之上的可视化工具

import seaborn as sns  # 用于统计数据可视化
import matplotlib.pyplot as plt

sns.set_theme()

tips_df = sns.load_dataset('tips')
tips_df.info()

# 账单金额的分布
sns.histplot(data=tips_df, x='total_bill', kde=True)
